# %% [markdown]
# <a href="https://colab.research.google.com/github/codingshinobi/mlprojects/blob/gh-pages/Naukri.com_jobs_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Questions to be answered -----
#
#
# 1.   What positions are more available?
# 2.   What Skills are in demand?
# 3.   Which city/ state has more requirement of data scientists?
# 4.   How much experience is required?
# 5.   Which companies are hiring?
# 6.   How much are they paying?

# %%
# importing dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"E:\DATASETS\Naukri\SourcePro_NkriJobs___106071204.xlsx")
df.head()
# Out:
#                                            Job Title  \
# 0               Web Development/Data Science Trainee
# 1             Machine Learning/Data Science Engineer
# 2  Data Science Analyst-Cyber Security Analyst-Na...
# 3  Data Science Analyst-Cyber Security Analyst-Na...
# 4  Urgently hiring For Data science Analysts - Pu...
#
#                                              Job URL  \
# 0  https://www.naukri.com/job-listings-web-develo...
# 1  https://www.naukri.com/job-listings-machine-le...
# 2  https://www.naukri.com/job-listings-data-scien...
# 3  https://www.naukri.com/job-listings-data-scien...
# 4  https://www.naukri.com/job-listings-urgently-h...
#
#                                     Company Name  \
# 0              Musubi Management Private Limited
# 1                                   4ONLINEMEDIA
# 2                         ZINGO TECHSERVICES LLP
# 3                         ZINGO TECHSERVICES LLP
# 4  FIS Global Business Solutions India Pvt. Ltd.
#
#                                          Compnay URL      Exp  \
# 0  https://www.naukri.com/musubi-management-jobs-...  0-0 Yrs
# 1  https://www.naukri.com/4onlinemedia-jobs-caree...  0-5 Yrs
# 2  https://www.naukri.com/zingo-techservices-jobs...  0-3 Yrs
# 3  https://www.naukri.com/zingo-techservices-jobs...  0-3 Yrs
# 4  https://www.naukri.com/fis-global-business-sol...  4-9 Yrs
#
#                      Salary   Location  \
# 0   3,50,000 - 6,00,000 PA.  Bangalore
# 1   3,00,000 - 5,00,000 PA.  Bangalore
# 2             Not disclosed     Mumbai
# 3     50,000 - 1,00,000 PA.     Mumbai
# 4  5,00,000 - 15,00,000 PA.     Mumbai
#
#                                               Skills      Posted
# 0  Data Science|Web Development|IT Skills|Python|...    Just Now
# 1  Python|analytical|Data science|Tableau|machine...         NaN
# 2  Analytical|Security Analysis|Ethical Hacking|C...  2 Days Ago
# 3  Analytical|Security Analysis|Ethical Hacking|C...  2 Days Ago
# 4  Data Science|R|SAS|Artificial Intelligence|Sta...   1 Day Ago

# %%
df.tail()
# Out:
#                                               Job Title  \
# 1015                                  Python Programmer
# 1016                     Senior UX Desginer/UX Designer
# 1017                                   Business Analyst
# 1018  Data Scientist || IT Service Org || Bengaluru ...
# 1019         Full Stack Developer - Java/J2EE Framework
#
#                                                 Job URL  \
# 1015  https://www.naukri.com/job-listings-python-pro...
# 1016  https://www.naukri.com/job-listings-senior-ux-...
# 1017  https://www.naukri.com/job-listings-business-a...
# 1018  https://www.naukri.com/job-listings-data-scien...
# 1019  https://www.naukri.com/job-listings-full-stack...
#
#                    Company Name  \
# 1015                    Agreeya
# 1016                 Salesforce
# 1017               Novel Office
# 1018              Macrohire LLP
# 1019  Huquo Consulting Pvt. Ltd
#
#                                             Compnay URL       Exp  \
# 1015  https://www.naukri.com/agreeya-jobs-careers-28505   2-6 Yrs
# 1016  https://www.naukri.com/salesforce-jobs-careers...   3-6 Yrs
# 1017  https://www.naukri.com/novel-office-jobs-caree...   0-3 Yrs
# 1018  https://www.naukri.com/macrohire-jobs-careers-...  6-11 Yrs
# 1019  https://www.naukri.com/premium-jobs-careers-85...   3-7 Yrs
#
#              Salary                   Location  \
# 1015  Not disclosed                    Gurgaon
# 1016  Not disclosed                  Hyderabad
# 1017  Not disclosed  Bangalore(Koramangala +4)
# 1018  Not disclosed                  Bangalore
# 1019  Not disclosed                  Bangalore
#
#                                                  Skills       Posted
# 1015  Business process|Data analysis|development tes...          NaN
# 1016  Product management|User research|Product launc...          NaN
# 1017  Data Science|Data Research|Business Analytics|...  21 Days Ago
# 1018  IT Skills|Python|Data Science|Machine Learning...   5 Days Ago
# 1019  IT Skills|Java|J2EE|Python|Software Developmen...   7 Days Ago

# %%
df= df.dropna()
df.shape
# Out:
# (893, 9)

# %%
#lets lower case all the strings to avoid redundancy
df=df.apply(lambda x: x.astype(str).str.lower())

#there are more than one location and skill are attcahed to each job, so lets split Location and jobs.
df.Skills=[Skills.split("|") for Skills in df.Skills]
df.Location=[Location.split(",") for Location in df.Location]

# %%
df.head()
# Out:
#                                            Job Title  \
# 0               web development/data science trainee
# 2  data science analyst-cyber security analyst-na...
# 3  data science analyst-cyber security analyst-na...
# 4  urgently hiring for data science analysts - pu...
# 5                               data science analyst
#
#                                              Job URL  \
# 0  https://www.naukri.com/job-listings-web-develo...
# 2  https://www.naukri.com/job-listings-data-scien...
# 3  https://www.naukri.com/job-listings-data-scien...
# 4  https://www.naukri.com/job-listings-urgently-h...
# 5  https://www.naukri.com/job-listings-data-scien...
#
#                                     Company Name  \
# 0              musubi management private limited
# 2                         zingo techservices llp
# 3                         zingo techservices llp
# 4  fis global business solutions india pvt. ltd.
# 5               jpmorgan services india pvt. ltd
#
#                                          Compnay URL      Exp  \
# 0  https://www.naukri.com/musubi-management-jobs-...  0-0 yrs
# 2  https://www.naukri.com/zingo-techservices-jobs...  0-3 yrs
# 3  https://www.naukri.com/zingo-techservices-jobs...  0-3 yrs
# 4  https://www.naukri.com/fis-global-business-sol...  4-9 yrs
# 5  https://www.naukri.com/jpmorgan-services-india...  4-9 yrs
#
#                      Salary              Location  \
# 0   3,50,000 - 6,00,000 pa.           [bangalore]
# 2             not disclosed              [mumbai]
# 3     50,000 - 1,00,000 pa.              [mumbai]
# 4  5,00,000 - 15,00,000 pa.              [mumbai]
# 5             not disclosed  [mumbai,  bangalore]
#
#                                               Skills      Posted
# 0  [data science, web development, it skills, pyt...    just now
# 2  [analytical, security analysis, ethical hackin...  2 days ago
# 3  [analytical, security analysis, ethical hackin...  2 days ago
# 4  [data science, r, sas, artificial intelligence...   1 day ago
# 5  [data science, r, artificial intelligence, exp...   1 day ago

# %% [markdown]
# # 1. Let's see which city currently has most demand for the data scientists.

# %%
df.Location.apply(pd.Series).stack().str.strip().value_counts()[:10].plot.pie(figsize=(12,10),startangle=50,autopct='%1.1f%%',fontsize=15)
plt.title("Location Wise Data scientist Jobs",fontsize=30)
centre_circle = plt.Circle((0,0),0.72,color='gray', fc='white',linewidth=1.25)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal')
plt.show()

# %% [markdown]
# **No surprises here.**

# %% [markdown]
# # 2. What Skills are in demand?

# %%
df.Skills.apply(pd.Series).stack().value_counts()[:50].plot(kind="bar",figsize=(18,6),fontsize=15,color="b")
plt.xticks(rotation=50,ha='right')
#plt.title("Top Skills for Data science",fontsize=25)
plt.ylabel("No.of Vacancies",fontsize=20)
plt.xlabel("Top Skills for Data science",fontsize=25)
plt.show()

# %% [markdown]
# These are the top 50 skills that the recruiters have mentioned. If we look past **Data Science** (as it is the umbrella term for everything), we find **ML, Python, IT Skills, Data analysis, AI, SQL, Tableau** to be the most important skills to have for the job.

# %%
# If we were to look for a more precise answer
top_skills = pd.DataFrame(df.Skills.apply(pd.Series).stack().value_counts()).reset_index()
top_skills.columns = ["Skill", "Count"]
top_skills.head(6)
# Out:
#                      Skill  Count
# 0             data science    509
# 1         machine learning    316
# 2                   python    308
# 3                it skills    252
# 4            data analysis    176
# 5  artificial intelligence    151

# %% [markdown]
# # 3. Which companies are hiring?

# %%
df["Company Name"].value_counts()[:10].plot.pie(figsize=(12,10),explode=[0.03,0.04,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05],shadow=True, startangle=40,autopct='%1.1f%%',fontsize=15)
plt.title("Companies that are hiring",fontsize=25)
plt.show()

# %% [markdown]
# As we see from the chart that Accenture is hiring the most followed by IBM.

# %%
print(df['Company Name'].value_counts())
# Out:
# accenture solutions pvt ltd                      118
# ibm india pvt. limited                            51
# huquo consulting pvt. ltd                         46
# capgemini technology services india limited       12
# talpro                                            11
#                                                 ...
# isparrow hr solutions                              1
# suyati technologies pvt ltd                        1
# unison international consulting pvt. ltd           1
# fis global business solutions india pvt. ltd.      1
# innovative trending solutions                      1
# Name: Company Name, Length: 439, dtype: int64

# %% [markdown]
# # 4. Popular roles offered

# %%
df['Job Title'].value_counts()[:10]
# Out:
# data scientist                                          26
# senior analyst-data science                             12
# data analyst                                            11
# microsoft modern data platform application developer    10
# team lead/consultant-data science                        9
# acn - digital - data & insights - 09                     7
# data science                                             6
# analyst - risk and compliance                            6
# analyst-data science                                     6
# business analyst: adm                                    5
# Name: Job Title, dtype: int64

# %% [markdown]
# These are the top 10 roles that are offered. Data scientist, data analystand Business analyst are the ones that are most popular.

# %% [markdown]
# #5. How much experience are they looking?

# %%
print(df['Exp'].value_counts())
# Out:
# 5-10 yrs     71
# 4-9 yrs      45
# 2-7 yrs      43
# 3-5 yrs      40
# 7-12 yrs     38
#              ..
# 18-20 yrs     1
# 12-20 yrs     1
# 15-17 yrs     1
# 15-24 yrs     1
# 12-14 yrs     1
# Name: Exp, Length: 77, dtype: int64

# %% [markdown]
# As we can see that, the companies are looking for experienced prifessionals, most of them want candidates from 4 to 10 years of experienced. This is bad for people like me!!

# %% [markdown]
# # 6. How much are they paying?

# %%
df['Salary'].value_counts()
# Out:
# not disclosed                753
# 15,00,000 - 30,00,000 pa.      6
# 8,00,000 - 12,00,000 pa.       5
# 15,00,000 - 25,00,000 pa.      5
# 4,00,000 - 6,00,000 pa.        4
#                             ...
# 1,75,000 - 3,00,000 pa.        1
# 8,00,000 - 10,00,000 pa.       1
# 7,00,000 - 11,00,000 pa.       1
# 70,000 - 1,25,000 pa.          1
# 20,00,000 - 27,50,000 pa.      1
# Name: Salary, Length: 88, dtype: int64

# %% [markdown]
# Too hard to find a patteren here, as most of them haven't disclosed the salary.

# %% [markdown]
# PS- I performed some basic data cleaning in EXCEL itself.
